# %% [markdown]
# # SCIPY-

# %%
import numpy as np
from scipy import special
from scipy.stats import norm
import seaborn as sns

# %%
mean,std=50,10

#probability that x<=40
p=norm.cdf(40,loc=mean,scale=std)
print(p)
# Out:
# 0.15865525393145707

# %%
import numpy as np
data=[45, 56, 67, 48, 59, 72, 65, 80, 91, 52,
 47, 60, 73, 68, 81, 50, 55, 62, 77, 85,
 58, 63, 70, 75, 83, 90, 42, 46, 53, 61,
 49, 57, 64, 71, 78, 82, 88, 93, 95, 40,
 44, 54, 66, 69, 74, 79, 84, 87, 92, 96,
 41, 43, 51, 76, 86, 89, 94, 97, 99, 100]

# %%
mean=np.mean(data)
std=np.std(data)
cdf_value=norm.cdf(60,loc=mean,scale=std)
print(cdf_value)
# Out:
# 0.2916095541382925

# %%
cdf_value=norm.cdf(80,loc=mean,scale=std)
print(cdf_value*100)
# Out:
# 72.65481962600717

# %%
z_score=90-mean/std
print(z_score)
# Out:
# 85.99802583921432

# %%
df=sns.load_dataset('iris')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.kdeplot(data=df,x='petal_length',hue='species')
# Out:
# <Axes: xlabel='petal_length', ylabel='Density'>

# %%
titanic=sns.load_dataset('titanic')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.kdeplot(data=titanic,x='age',hue='survived')
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %%
import pandas as pd
age=pd.read_csv(r"C:\Users\Prince Chandravat\Downloads\ages_dataset.csv")
std=np.std(age)
mean=np.mean(age)

sns.kdeplot(age)
# Out:
# C:\Users\Prince Chandravat\venv\Lib\site-packages\numpy\_core\fromnumeric.py:4062: FutureWarning: The behavior of DataFrame.std with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
# <Axes: ylabel='Density'>

# %%
standard=age-mean/std
standard
sns.kdeplot(standard)
x=(age['Age']-age['Age'].mean())/age['Age'].std()
sns.kdeplot(x)
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.kdeplot(x)
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
import matplotlib.pyplot as plt
fig, axes = plt.subplots(1, 2, figsize=(12,5))

# Original Age
sns.histplot(age['Age'], kde=True, bins=30, ax=axes[0])
axes[0].set_title("Original Age Distribution")

# Standardized Age
sns.histplot(age['Age'], kde=True, bins=30, ax=axes[1])
axes[1].set_title("Standardized Age Distribution (Z-scores)")

plt.show()
